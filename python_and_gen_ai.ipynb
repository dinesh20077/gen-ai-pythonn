# %% [markdown]
# <a href="https://colab.research.google.com/github/dinesh20077/gen-ai-pythonn/blob/main/python_and_gen_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 10
x
# Out:
# 10

# %% [markdown]
# # New Section

# %%
y=20

# %%
y
# Out:
# 20

# %%
my_sub= "Generative ai"
my_sub
# Out:
# 'Generative ai'

# %%
_mycity ="solan"
_mycity
# Out:
# 'solan'

# %%
my_city1 = "new delhi"
my_city1
# Out:
# 'new delhi'

# %%
from os import uname
my_college ="shoolini"
my_city="una"
my_city
# Out:
# 'una'

# %%
import keyword
keyword. kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ***data type in python***

# %%
x=1
type(x)
# Out:
# int

# %%
y=6.6
type(y)
# Out:
# float

# %%
z=3+4j
type(z)
# Out:
# complex

# %%
#string --- data in the form of text
a="una"
type(a)
# Out:
# str

# %%
x=True
type(x)
# Out:
# bool

# %%
y=False
type(y)
# Out:
# bool

# %%
d=None
type(d)
# Out:
# NoneType

# %% [markdown]
# **OPERATOR**

# %%
#ADDITOIN
2+2
# Out:
# 4

# %%
x=4
y=5
z=x+y
print(z)
# Out:
# 9

# %%
#subtraction
a=48
b=48
z=a-b

print(z)
# Out:
# 0

# %%
#multiple
a=5
b=4
c=a*b
print(c)
# Out:
# 20

# %%
#division
a=50
b=5
c=a/b
print(c)
# Out:
# 10.0

# %%
#expontiation
a=2
b=5
c=a**b
print(c)
# Out:
# 32

# %%
x=3**5
print(x)
# Out:
# 243

# %%
#floor division
a=7//2
b=50//2
print(a)
print(b)
# Out:
# 3
# 25

# %%
8.9//2
# Out:
# 4.0

# %%
#modulous---gives result is remainder
5%-2
# Out:
# -1

# %% [markdown]
# data sturcture in python

# %%
#find the length of string
my_sub="machine learning"
len(my_sub)
# Out:
# 16

# %% [markdown]
# +ve idexing

# %%
my_sub [0]
# Out:
# 'm'

# %%
my_sub[7]
# Out:
# ' '

# %% [markdown]
# -ve ***indexing***

# %%
my_sub[-2]
# Out:
# 'n'

# %%
my_sub[-7]
# Out:
# 'e'

# %% [markdown]
# **slicing**

# %%
my_sub[0:7:1]
# Out:
# 'machine'

# %%
my_sub[8:16:1]
# Out:
# 'learning'

# %%
my_sub[0:7] #bydeafault stepsize is 1
# Out:
# 'machine'

# %% [markdown]
# lower method

# %%
my_sub="PYTHON"
my_sub.lower()
# Out:
# 'python'

# %% [markdown]
# **upper**

# %%
my_sub="python"
my_sub.upper()
# Out:
# 'PYTHON'

# %%
#count
my_string="machine learning"
my_string.count('a')
# Out:
# 2

# %%
my_string="machine learning"
my_string.count('n')
# Out:
# 3

# %%
#list
my_list=[45,67,43,56]
type(my_list)
# Out:
# list

# %%
#mixed  list
mixed_list=[45,"apple",None]
type(mixed_list)
# Out:
# list

# %%
print  (my_list)
# Out:
# [45, 67, 43, 56]

# %%
# find the length of list
len (my_list)
# Out:
# 4

# %%
#positive indexing
my_list=[45,56,46,67,56]
print (my_list[0])
print (my_list[1])
print (my_list[2])
print (my_list[3])
print (my_list[4])
# Out:
# 45
# 56
# 46
# 67
# 56

# %%
#negative indexing
my_list=[45,56,78,56,45]
print (my_list[-1])
print (my_list[-2])
print (my_list[-3])
print (my_list[-4])
print (my_list[-5])
# Out:
# 45
# 56
# 78
# 56
# 45

# %% [markdown]
# slicing is **list**

# %%
my_list=[3,4,5,6,7,1]
my_list[0:5:1]
# Out:
# [3, 4, 5, 6, 7]

# %%
#by deafault stepsize is one
my_list[0:5]
# Out:
# [3, 4, 5, 6, 7]

# %%
my_list[0:]
# Out:
# [3, 4, 5, 6, 7, 1]

# %%
my_list[:5]
# Out:
# [3, 4, 5, 6, 7]

# %%
# list in opposite  direction
my_list=[45,56,78,56,47]
my_list [::-1]
# Out:
# [47, 56, 78, 56, 45]

# %%
#function in list
#min ()-- return  the  minimun number of list
my_list=[45,67,47,78,48]
min(my_list)
# Out:
# 45

# %%
#max
max(my_list)
# Out:
# 78

# %%
#sum
sum(my_list)
# Out:
# 285

# %%
#sorted list
list1=[4,6,7,8,9,3]
sorted(list1)
# Out:
# [3, 4, 6, 7, 8, 9]

# %%
sorted(list1,reverse=True)
# Out:
# [9, 8, 7, 6, 4, 3]

# %%
#append
my_list=[34,45,56,45]
print(my_list)
my_list.append(100)
print(my_list)
# Out:
# [34, 45, 56, 45]
# [34, 45, 56, 45, 100]

# %%
my_list
# Out:
# [34, 45, 56, 45, 100]

# %%
my_list[3]=300
print (my_list)
# Out:
# [34, 45, 56, 300, 100]

# %%
my_list[4]=300
print(my_list)
# Out:
# [34, 45, 56, 300, 300]

# %%
#extend
list1=[34,56,78]
list2=[67,54,67]
list1.extend(list2)
print(list1)
# Out:
# [34, 56, 78, 67, 54, 67]

# %%
#pop
my_list=[45,34,55,23]
my_list.pop()
# Out:
# 23

# %%
#remove
list1=[56,67,45,66]
list1.remove(67)
list1
# Out:
# [56, 45, 66]

# %%
#reverse
my_list=[45,67,89,67]
my_list.reverse()
print(my_list)
# Out:
# [67, 89, 67, 45]

# %%
#dictionary
my_dict={"Name":"Dinesh","college":"shoolini university"}
type(my_dict)
# Out:
# dict

# %%
print(my_dict)
# Out:
# {'Name': 'Dinesh', 'college': 'shoolini university'}

# %%
print(my_dict["Name"])
print(my_dict["college"])
# Out:
# Dinesh
# shoolini university

# %%
#method of dictionary
#keys method
list(my_dict.keys())
# Out:
# ['Name', 'college']

# %%
#value method
my_dict.values()
# Out:
# dict_values(['Dinesh', 'shoolini university'])

# %%
list (my_dict.values())
# Out:
# ['Dinesh', 'shoolini university']

# %%
#items method
list(my_dict.items())
# Out:
# [('Name', 'Dinesh'), ('college', 'shoolini university')]

# %%
#get method
my_dict.get("Name")
# Out:
# 'Dinesh'

# %%
print (my_dict.get("age"))
# Out:
# None

# %%
print(my_dict.get("age","age is not present"))
# Out:
# age is not present

# %%
#update method
my_dict.update({"age":18})
print(my_dict)
# Out:
# {'Name': 'Dinesh', 'college': 'shoolini university', 'age': 18}

# %%
my_dict.update({"Name":"dishu"})
print(my_dict)
# Out:
# {'Name': 'dishu', 'college': 'shoolini university', 'age': 18}

# %%
#dictionary
my_dict={"Name":"Dinesh","college":"shoolini university"}
my_dict.update({"Name":"dishu"})
print(my_dict)
# Out:
# {'Name': 'dishu', 'college': 'shoolini university'}

# %%
#conditional statement
age=input("Enter youe age")
age=int(input ("Enter your age:"))
if age>60:
  print("you are too old for marry")
elif age<18:
  print ("you are too young for marry")
else:
  print("we will find perfect match for you")

# %% [markdown]
# **LOOPS**

# %%
my_sub="python"
print (my_sub[0])
print(my_sub[1])
print(my_sub[2])
print(my_sub[3])
print(my_sub[4])
print(my_sub[5])
# Out:
# p
# y
# t
# h
# o
# n

# %%
my_sub="python"
for i in my_sub:
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range (0,6,1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (0,6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
my_sub="python"
for i in range (len(my_sub)):
  print(my_sub[i],"->",i)
# Out:
# p -> 0
# y -> 1
# t -> 2
# h -> 3
# o -> 4
# n -> 5

# %%
my_sub="python"
for i in range (len(my_sub)):
  print(my_sub[i],"-",i)
# Out:
# p - 0
# y - 1
# t - 2
# h - 3
# o - 4
# n - 5

# %%
#while loop
i=0 #inilization
while i<5: #condition
  print(i)
  i+=1 #increment
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# loop and control *statement*

# %%
# loop and control statement
#break--
i=0
while i<5: #condition
  i+=1 #incriment
  if i==3:
    break
  else:
    print(i)
# Out:
# 1
# 2

# %%
i=0
while i<5:
  i+=1
  if i==4:
    break
  else:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# continues statement
i=0
while i<5:
  i+=1
  if i==3:
    continue
  else:
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#pass statement
i=0
while i<5:
  i+=1
  if i==4:
    pass
    print(i)
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # New Section

# %% [markdown]
# **functions**

# %%
#user defined function without argument
def add ():
  a=int(input("Enter the fist number:"))
  b=int(input ("Enter the second number:"))
  return a+b

# %%
add()
# Out:
# Enter the fist number:4
# Enter the second number:5
# 9

# %%
def add ():
  a=(input("Enter the first number"))
  b=(input("Enter the second number"))
  return a+b

# %%
add()
# Out:
# Enter the fist number:4
# Enter the second number:3
# 7

# %%
#positional argument
def calculation (a,b):
  print("addition",a+b)
  print("subtraction",a-b)
  print("multiplication",a*b)
  print("division",a/b)
  return "calculation is complete"

# %%
print(calculation(10,5))

# %%
#default argument
def area_perimeter(width=4, height=8):
  area = width*height
  perimeter =2*(width + height)
  return "Area is ",area,"and perimeter is ",perimeter

# %%
print(area_perimeter())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3211994167.py in <cell line: 0>()
# ----> 1 print(area_perimeter())
#
# NameError: name 'area_perimeter' is not defined

# %%
print (area_perimeter(14))
# it take 14 as width boc 14 is first argument
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1636492686.py in <cell line: 0>()
# ----> 1 print (area_perimeter(14))
#       2 # it take 14 as width boc 14 is first argument
#
# NameError: name 'area_perimeter' is not defined

# %%
print (area_perimeter(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-162669745.py in <cell line: 0>()
# ----> 1 print (area_perimeter(10,5))
#
# NameError: name 'area_perimeter' is not defined

# %%
#keyword argument
def interest(p,r,t):
  i=(p*r*t)/100
  return i

# %%
print (interest(r=10,t=2,p=1000))
# Out:
# 200.0

# %%
print (interest (r=45,t=10,p=2000))
# Out:
# 9000.0

# %%
#mixed argument
#positional argument follow keyword argument
print (interest(1000,r=10,t=2))
# Out:
# 200.0

# %%
#variable length argument
#non keyword positional variable lenght argument
def test (*args):
    print(args)
    print (len(args))
    print (type(args))

# %%
test(2,3,4,5,6,7,8)
# Out:
# (2, 3, 4, 5, 6, 7, 8)
# 7
# <class 'tuple'>

# %%
test (2.2,5,4,5,2.5)

# %%
# sum_number
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
    return sum

# %%
sum_number(3,5,7,3,6,5)
# Out:
# 3

# %%
sum_number(3,4,5,3,)
# Out:
# 3

# %%
def multiply(*numbers):
  product=1
  for number in numbers:
    product*=number
    return product

# %%
print(multiply(3,6,5))
# Out:
# 3

# %%
# make a function of multiplication of any numbere with the help of non-keyword positional variable length argument
def multi_number(*args)
multi=0
for multiple in args:
  multi*=multiple
# Out:
#   File "/tmp/ipython-input-412136894.py", line 2
#     def multi_number(*args)
#                            ^
# SyntaxError: expected ':'

# %%
# keyword variable length argument
def test (**kwargs):
  print (kwargs)
  print (len(kwargs))
  print (type(kwargs))

# %%
test(a=10,b=20,c=30)
# Out:
# {'a': 10, 'b': 20, 'c': 30}
# 3
# <class 'dict'>

# %%
def pass_student(**kwargs):
  pass_student_list=[]
  for name,marks in kwargs.items():
    if marks>40:
      pass_student_list.append (name)
  return pass_student_list

# %%
pass_student(A=30, B=40, C=50, D=80, E=20)
# Out:
# ['C', 'D']

# %% [markdown]
# ## **library**

# %%
# numpy
# import numpy as np
import numpy as np

# %%
#one D arrayj
print (oned_array)
# Out:
# [1 2 3 4]

# %% [markdown]
# **NUMPY LIBRARY**

# %%
# NUMPY - NUMERICAL PYTHON
#IT IS USED IN MATHEMATICS
# DATA STRUCTURE OF NUMPY IS MULTIDIMENSIONAL ARRAY.
# ARRY - COLLECTION OF ITEMS . IT IS HOMOGENEOUS.
# 1D COLLECTION-[1,2,3]
#2D- {[1,2,3][3,4,5]}
#3D- COLLECTION OF 2D
#import-is a keyword

# %%
import numpy as np

# %%
# practical on 1d array
oned_array=np.array([1,2,3])
print(oned_array)
# Out:
# [1 2 3]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1834721125.py in <cell line: 0>()
# ----> 1 arr=np.array(10,50)
#       2 print(arr)
#
# TypeError: Cannot interpret '50' as a data type

# %%
oned_array=np.array({10,50})
print (oned_array)
# Out:
# {10, 50}

# %%
import numpy as np
a = np.array([10, 20, 30, 40, 50])
print("Mean:", np.mean(a))
print("Std Dev:", np.std(a))
# Out:
# Mean: 30.0
# Std Dev: 14.142135623730951

# %%
import numpy as np
a = np.array([1, 2, 3])    # Creates from list
b = np.arange(1, 4)        # Creates sequence automatically
print(a, b)
# Out:
# [1 2 3] [1 2 3]

# %%
import numpy as np
I = np.identity(3)
print(I)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#practical on 2d array
twod_array=np.array([[1,2,3],[4,5,6,]])
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# making column vector and row vector with the help of array

# %%
#row vector
row_vector=np.array([[1,2,3]])
print(row_vector)
# Out:
# [[1 2 3]]

# %%
column_vector=np.array([[1],[2],[3]])
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
column_vector=row_vector.transpose()
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
# ndim--find the dimension of vector
column_vector.ndim
# Out:
# 2

# %%
#size----find the number of itek
column_vector.size
# Out:
# 3

# %%
#shape--
column_vector.shape
#3--row
#1--column
# Out:
# (3, 1)

# %%
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
row_vector.shape
# Out:
# (1, 3)

# %%
print(row_vector)
# Out:
# [[1 2 3]]

# %%
twod_array=np.array([[1,2,3],[4,5,6,]])
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(twod_array[0])
# Out:
# [1 2 3]

# %%
print(twod_array[1])
# Out:
# [4 5 6]

# %%
print(twod_array[0][2])
# Out:
# 3

# %%
print(twod_array[1][2])
# Out:
# 6

# %%
print(twod_array[-1])
# Out:
# [4 5 6]

# %%
print(twod_array[0,1])
# Out:
# 2

# %%
print(twod_array[-1][-2])
# Out:
# 5

# %%
print(twod_array[0:2,0:2])
# Out:
# [[1 2]
#  [4 5]]

# %%
print(twod_array[0:1,0:2])
# Out:
# [[1 2]]

# %%
threed_array=np.random.randint(1,10,(3,3))
print(threed_array)
# Out:
# [[3 5 8]
#  [7 7 9]
#  [4 1 8]]

# %%
print(threed_array[0:2,0:2])
# Out:
# [[3 5]
#  [7 7]]

# %% [markdown]
# **matrix**

# %%
import numpy as np
mat1 =np.matrix("1,2,3;4,5,6;7,8,9")
print(mat1)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
mat2=np.matrix([[1,2,3],[4,5,6]])
print (mat2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
mat3 = np.random.random((3,3))
print(mat3)
# Out:
# [[0.30261175 0.30924079 0.3644034 ]
#  [0.17467543 0.92035481 0.44257186]
#  [0.72239976 0.49548822 0.47589425]]

# %%
mat4=np.random.randint(1,10,(3,3,))
print(mat4)
# Out:
# [[7 2 3]
#  [3 3 2]
#  [5 7 1]]

# %%
zeros_array=np.zeros((3,3),dtype=int)
print(zeros_array)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
zeros_array=np.zeros((3,3))
print(zeros_array)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
ones_array=np.ones((3,3),dtype=int)
print(ones_array)
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]

# %%
print(ones_array*100)
# Out:
# [[100 100 100]
#  [100 100 100]
#  [100 100 100]]

# %%
my_array=np.full((3,3),10)
print(my_array)
# Out:
# [[10 10 10]
#  [10 10 10]
#  [10 10 10]]

# %%
my_array=np.array([1,2,3,4])
print(my_array)
# Out:
# [1 2 3 4]

# %%
power_array=np.power(my_array,2)
print(power_array)
# Out:
# [ 1  4  9 16]

# %%
power_array=np.power(my_array,3)
print(power_array)
# Out:
# [ 1  8 27 64]

# %%
print(my_array)
# Out:
# [1 2 3 4]

# %%
#expositation
exp_array=np.exp(my_array)
print(exp_array)
# Out:
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
#log-array
import numpy as np
log_array=np.log(my_array)
print(log_array)
# Out:
# [0.         0.69314718 1.09861229 1.38629436]

# %%
my_array=np.array([1,2,3,4])
print(my_array)
# Out:
# [1 2 3 4]

# %%
log2_array=np.log2(my_array)
print(log2_array)
# Out:
# [0.        1.        1.5849625 2.       ]

# %%
log10_array=np.log10(my_array)
print(log10_array)
# Out:
# [0.         0.30103    0.47712125 0.60205999]

# %%
import numpy as np

# %%
a=np.random.randint(1,10,(2,3))
b=np.random.randint(1,10,(3,2))
print(a)
print(b)
# Out:
# [[3 6 6]
#  [1 7 5]]
# [[3 6]
#  [1 2]
#  [2 3]]

# %%
print(np.dot(a,b))
# Out:
# [[27 48]
#  [20 35]]

# %% [markdown]
# # **matplotlib**

# %%
#it is python library
#it is use for data visualization

# %%
# how to import
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoint=np.array([1,3,])
ypoint=np.array([2,4])
plt.plot(xpoint,ypoint)
plt.show()

# %%
cgpa=np.array([7.5,8,9,9.5,10,7.5,8])
package=np.array([8,7.3,12,23,8.5,15,9])
plt.plot(cgpa,package,"*:b",ms=15,mec="lightgreen",linewidth=5.8)
# ms=marker size,mec=marker edge color
font1={"family":"serif","color":"blue","size":20}   #family=text style
font2={"family":"serif","color":"red","size":25}
plt.xlabel("cgpa",fontdict=font1)
plt.ylabel("package",fontdict=font1)
plt.title("shoolini university student data",fontdict=font2)
plt.grid(color="black",linestyle="-",linewidth="1.2")
plt.show()

# %% [markdown]
# # **Barplot**

# %%
# it is work on numerical as well as catigorical data
# e.g- apple ,bannana, orange(categorical data)
# quantity of fruit --100k,200,100( it is a numerical data)

# %%
import matplotlib.pyplot as plt
import numpy as np
fruit= np.array(["apple","banana","orange","watermelon"])
quantity=np.array([100,200,100,50])
color=np.array(["red","yellow","orange","green"])
plt.bar(fruit,quantity, color=color)

plt.title("fruit graph" )
plt.xlabel("fruit")
plt.ylabel("quantity")
plt.show()

# %%
fruit= np.array(["apple","banana","orange","watermelon"])
quantity=np.array([100,200,100,50])
color=np.array(["red","yellow","orange","green"])
plt.barh(fruit,quantity, color=color)

plt.title("fruit graph" )
plt.xlabel("fruit")
plt.ylabel("quantity")
plt.show()

# %% [markdown]
# # **pieplot**

# %%
#pie plot

# %%
import matplotlib.pyplot as plt
import numpy as np
fruit= np.array(["apple","banana","orange","watermelon"])
myexplode=[0.2,0,0,0]
quantity=np.array([100,200,100,50])
color=np.array(["red","yellow","orange","lightgreen"])
plt.pie(quantity, labels=fruit, colors=color, explode=myexplode)# myexplode is used to remove anything from pir graph just like as apple section
font1={"family":"serif","color":"blue","size":25}
plt.title("fruit graph" ,fontdict=font1)
plt.legend(title="fruit",loc="lower left")# upper right,upper left, lower right ,lowerleft and another is best
plt.show()

# %% [markdown]
# # **scatter plot**

# %%
age_of_car=np.array([4,6,8,10,12,16])
speed_of_car=np.array([220,180,150,120,110,100])
plt.scatter(age_of_car,speed_of_car)
font1={"family":"serif","color":"blue","size":"20"}

plt.xlabel("age of car")
plt.ylabel("speed of car")
plt.title("age and speed of car")
plt.show()

# %% [markdown]
# # **histogram**

# %%
# it shows frequency distribution

# %%
import numpy as np
x=np.random.randint(40,100,(1,200))
x=x.flatten()# flatten convert data in 1d
print(x)
# Out:
# [50 40 89 78 41 74 40 88 70 67 77 58 95 84 40 79 93 42 55 67 68 67 52 70
#  47 45 77 55 40 70 45 83 95 65 63 78 56 49 76 85 79 44 47 47 50 59 91 64
#  63 88 91 74 83 63 78 41 87 97 84 50 47 94 53 98 75 77 77 45 70 80 79 67
#  97 82 79 70 87 57 71 65 54 79 72 80 62 75 58 77 85 54 93 51 67 58 53 64
#  94 78 47 80 43 60 46 55 86 99 59 94 44 76 57 95 42 55 47 54 87 58 67 76
#  94 97 67 87 57 71 83 41 69 97 74 45 82 60 94 73 50 47 46 44 71 70 94 94
#  40 70 89 85 54 82 48 75 62 58 82 82 94 91 74 72 61 57 71 74 80 66 47 94
#  48 84 51 90 49 43 84 98 56 59 60 67 52 66 49 43 88 78 96 42 70 88 59 73
#  78 64 57 42 50 55 53 61]

# %%
import matplotlib.pyplot as plt
plt.hist(x, bins=25)
plt.show()

# %% [markdown]
# # **pandas library**

# %%
import pandas as pd

# %%
#series -- one dimensional data structure of pandas
my_series=pd.Series(["Apple","Banana","Mango","Orange"],name="fruit")
my_series
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# 3    Orange
# Name: fruit, dtype: object

# %%
#DataFrame-- two dimensional data structure of pandas
list_into_list=[["Amar",15],["Akbar",14],["Anthony",13]]
df=pd.DataFrame(list_into_list,columns=["Name","Age"])
df
# Out:
#       Name  Age
# 0     Amar   15
# 1    Akbar   14
# 2  Anthony   13

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/data/imdb_data.csv")
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 23 columns]

# %%
#head()--bring rows(data point)from top of the dataframe
df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
#
# [2 rows x 23 columns]

# %%
df.head(100)
# Out:
#      id                              belongs_to_collection    budget  \
# 0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2     3                                                NaN   3300000
# 3     4                                                NaN   1200000
# 4     5                                                NaN         0
# ..  ...                                                ...       ...
# 95   96                                                NaN         0
# 96   97                                                NaN   2500000
# 97   98                                                NaN         0
# 98   99                                                NaN  10500000
# 99  100                                                NaN   6000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ..                                                ...
# 95                      [{'id': 18, 'name': 'Drama'}]
# 96  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 97  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 98  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 99  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# ..                                ...        ...               ...
# 95                                NaN  tt2569398                ru
# 96                                NaN  tt1683921                fr
# 97                                NaN  tt1772980                ru
# 98                                NaN  tt1764625                es
# 99                                NaN  tt0094894                en
#
#                               original_title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                       마린보이
# ..                                       ...
# 95                Со мною вот что происходит
# 96                              Nuit Blanche
# 97                                    Mishen
# 98              Las aventuras de Tadeo Jones
# 99                                    Colors
#
#                                              overview  popularity  ...  \
# 0   When Lou, who has become the "father of the In...    6.575393  ...
# 1   Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2   Under the direction of a ruthless instructor, ...   64.299990  ...
# 3   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4   Marine Boy is the story of a former national s...    1.148070  ...
# ..                                                ...         ...  ...
# 95  December, 31st. Impossible Moscow traffic, an ...    0.181963  ...
# 96  Vincent is a crooked cop whose drug heist goes...    2.942355  ...
# 97  In the year 2020, a group of wealthy Moscovite...    1.042112  ...
# 98  Tad is a celebrity archeologist and adventurer...   11.003515  ...
# 99  A confident young cop is shown the ropes by a ...    5.529808  ...
#
#    release_date runtime                                   spoken_languages  \
# 0       2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1        8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2      10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4        2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ..          ...     ...                                                ...
# 95      12/9/12    72.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 96     11/14/11    98.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 97      6/26/11   158.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 98      8/31/12    90.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 99      4/15/88   120.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#       status                                            tagline  \
# 0   Released  The Laws of Space and Time are About to be Vio...
# 1   Released  It can take a lifetime to find true love; she'...
# 2   Released    The road to greatness can take you to the edge.
# 3   Released                                                NaN
# 4   Released                                                NaN
# ..       ...                                                ...
# 95  Released                                                NaN
# 96  Released                                                NaN
# 97  Released                                                NaN
# 98  Released                         No whip, no gun...All fun!
# 99  Released   70,000 gang members. One million guns. Two cops.
#
#                                        title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                 Marine Boy
# ..                                       ...
# 95         And Here's What's Happening to Me
# 96                           Sleepless Night
# 97                                    Target
# 98                    Tad, the Lost Explorer
# 99                                    Colors
#
#                                              Keywords  \
# 0   [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98  [{'id': 720, 'name': 'helicopter'}, {'id': 145...
# 99  [{'id': 796, 'name': 'police brutality'}, {'id...
#
#                                                  cast  \
# 0   [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ..                                                ...
# 95  [{'cast_id': 4, 'character': 'Artyom', 'credit...
# 96  [{'cast_id': 1, 'character': 'Vincent', 'credi...
# 97  [{'cast_id': 1001, 'character': 'Victor', 'cre...
# 98  [{'cast_id': 2, 'character': 'Sara', 'credit_i...
# 99  [{'cast_id': 1, 'character': 'Officer Danny Mc...
#
#                                                  crew   revenue
# 0   [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1   [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ..                                                ...       ...
# 95  [{'credit_id': '52fe4b199251416c910cfbd9', 'de...     14353
# 96  [{'credit_id': '52fe49c0c3a368484e13dc9b', 'de...      3358
# 97  [{'credit_id': '58cdbad4c3a36850e9011085', 'de...     73000
# 98  [{'credit_id': '52fe4a6bc3a368484e15241f', 'de...  23000000
# 99  [{'credit_id': '52fe432f9251416c75006ac5', 'de...  46616067
#
# [100 rows x 23 columns]

# %%
#tail()-- bring the rows(data point) from bottom of the data frame
df.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996      3/28/13   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [5 rows x 23 columns]

# %%
df.tail(12)
# Out:
#         id                              belongs_to_collection    budget  \
# 2988  2989                                                NaN         0
# 2989  2990                                                NaN         0
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2988                      [{'id': 18, 'name': 'Drama'}]
# 2989  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language  \
# 2988                                   NaN  tt0301978                fa
# 2989                                   NaN  tt0206367                en
# 2990                                   NaN  tt0118663                en
# 2991                                   NaN  tt0206275                en
# 2992                                   NaN  tt0015400                en
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
# 2994                                   NaN  tt0105327                en
# 2995                                   NaN  tt0109403                en
# 2996                                   NaN  tt2364975                sv
# 2997                                   NaN  tt0116908                en
# 2998        http://www.alongcamepolly.com/  tt0343135                en
# 2999      http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2988                       ده
# 2989  The Trumpet Of The Swan
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2988  A visual social examination in the form of ten...    0.984515  ...
# 2989  The adventures of a young Trumpeter swan who c...    0.851599  ...
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2991  A white midwestern girl moves to Chicago, wher...    4.794088  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 2988      5/20/02    94.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 2989      5/11/01    75.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2990      3/28/97    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2991      1/12/01   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2992      3/18/24   149.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 2993      6/17/04   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 2988  Released                                                NaN
# 2989  Released  Sometimes being different helps you to find yo...
# 2990  Released                These Pretty Women... Are Clueless!
# 2991  Released        The Only Person You Need To Be Is Yourself.
# 2992  Released                         "Happiness Must Be Earned"
# 2993  Released                                   Life is waiting.
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                         title  \
# 2988                      Ten
# 2989  The Trumpet Of The Swan
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2988  [{'id': 1156, 'name': 'sister sister relations...
# 2989  [{'id': 6653, 'name': 'trumpet'}, {'id': 10407...
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2988  [{'cast_id': 2, 'character': 'Driver', 'credit...
# 2989  [{'cast_id': 1, 'character': 'Father', 'credit...
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2991  [{'cast_id': 18, 'character': 'Sara Johnson', ...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2988  [{'credit_id': '52fe460a9251416c7506b0a7', 'de...     105656
# 2989  [{'credit_id': '58bc9d609251416084044b0e', 'de...     100202
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2991  [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...   91038276
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [12 rows x 23 columns]

# %%
#find the  number of rows and column in data frame
df.shape
# Out:
# (3000, 23)

# %%
#find the name of the all column
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
#bring the rows (data point) randomly from the data or dataframe
df.sample(5)
# Out:
#         id                              belongs_to_collection   budget  \
# 2522  2523  [{'id': 1960, 'name': 'Evil Dead Collection', ...  3600000
# 2276  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...        0
# 1576  1577                                                NaN  4000000
# 811    812                                                NaN        0
# 457    458                                                NaN   250000
#
#                                                  genres  \
# 2522  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 2276  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 1576                      [{'id': 18, 'name': 'Drama'}]
# 811                       [{'id': 18, 'name': 'Drama'}]
# 457                       [{'id': 18, 'name': 'Drama'}]
#
#                       homepage    imdb_id original_language  \
# 2522                       NaN  tt0092991                en
# 2276  http://www.deadsnow.com/  tt2832470                no
# 1576                       NaN  tt0335266                en
# 811                        NaN  tt0088707                en
# 457                        NaN  tt0105508                en
#
#            original_title                                           overview  \
# 2522         Evil Dead II  Ash Williams and his girlfriend Linda find a l...
# 2276            Død Snø 2  The gruesome Nazi Zombies are back to finish t...
# 1576  Lost in Translation  Two lost souls visiting Tokyo -- the young, ne...
# 811       American Flyers  When Dr. Marcus Sommers realizes that he and h...
# 457                 Swoon  In a film based on actual events, teenagers Na...
#
#       popularity  ... release_date runtime  \
# 2522   13.520764  ...      3/13/87    84.0
# 2276   10.287127  ...      2/12/14   100.0
# 1576   11.609441  ...      8/31/03   102.0
# 811     5.507510  ...      8/16/85   113.0
# 457     0.003013  ...      9/11/92    82.0
#
#                                        spoken_languages    status  \
# 2522           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2276  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 1576  [{'iso_639_1': 'ja', 'name': '日本語'}, {'iso_639...  Released
# 811            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 457            [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2522  The Sequel To The Ultimate Experience In Gruel...
# 2276                            Heads up. They're back.
# 1576                        Everyone wants to be found.
# 811   Two brothers challenge the road. And life itself.
# 457                                                 NaN
#
#                           title  \
# 2522               Evil Dead II
# 2276  Dead Snow 2: Red vs. Dead
# 1576        Lost in Translation
# 811             American Flyers
# 457                       Swoon
#
#                                                Keywords  \
# 2522  [{'id': 7946, 'name': 'deer'}, {'id': 8636, 'n...
# 2276  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 1576  [{'id': 213, 'name': 'upper class'}, {'id': 92...
# 811   [{'id': 3797, 'name': 'bicycle'}, {'id': 6075,...
# 457                                                 NaN
#
#                                                    cast  \
# 2522  [{'cast_id': 15, 'character': "Ashley 'Ash' J....
# 2276  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 1576  [{'cast_id': 2, 'character': 'Bob Harris', 'cr...
# 811   [{'cast_id': 1, 'character': 'Marcus Sommers',...
# 457   [{'cast_id': 1000, 'character': 'Richard Loeb'...
#
#                                                    crew    revenue
# 2522  [{'credit_id': '52fe4273c3a36847f801f88b', 'de...    5923044
# 2276  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...      37473
# 1576  [{'credit_id': '52fe421fc3a36847f8005b57', 'de...  119723856
# 811   [{'credit_id': '52fe45c69251416c75061fdb', 'de...    1400000
# 457   [{'credit_id': '52fe48b4c3a36847f81750e7', 'de...     340147
#
# [5 rows x 23 columns]

# %%
#find the infromation of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
#how does the data looklike mathematically
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
#find the duplicate value
print(df.duplicated().sum())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
#slicing and indexing
#find the single column with all row
df["title"]
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
#multiple column with all rows
df[["title","budget","revenue","status","original_language"]]
# Out:
#                                          title    budget    revenue    status  \
# 0                       Hot Tub Time Machine 2  14000000   12314651  Released
# 1     The Princess Diaries 2: Royal Engagement  40000000   95149435  Released
# 2                                     Whiplash   3300000   13092000  Released
# 3                                      Kahaani   1200000   16000000  Released
# 4                                   Marine Boy         0    3923970  Released
# ...                                        ...       ...        ...       ...
# 2995                                   Chasers         0    1596687  Released
# 2996                          We Are the Best!         0     180590  Released
# 2997                   The Long Kiss Goodnight  65000000   89456761  Released
# 2998                          Along Came Polly  42000000  171963386  Released
# 2999                                 Abduction  35000000   82087155  Released
#
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   hi
# 4                   ko
# ...                ...
# 2995                en
# 2996                sv
# 2997                en
# 2998                en
# 2999                en
#
# [3000 rows x 5 columns]

# %%
#slicing with help of rows
df[0:4]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
#
# [4 rows x 23 columns]

# %%
# find the sum number of rows and column
df.iloc[0:4,0:3]# ending index in iloc not included
# Out:
#    id                              belongs_to_collection    budget
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000

# %%
#loc method
df.loc[0:4,["title","budget","revenue"]]# ending index in loc method is included
# Out:
#                                       title    budget   revenue
# 0                    Hot Tub Time Machine 2  14000000  12314651
# 1  The Princess Diaries 2: Royal Engagement  40000000  95149435
# 2                                  Whiplash   3300000  13092000
# 3                                   Kahaani   1200000  16000000
# 4                                Marine Boy         0   3923970

# %%
#find the unique value in particular column
df["original_language"].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df["original_language"] =="en"# == is a comparision operator
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
df[df["original_language"] =="en"]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                 homepage    imdb_id original_language  \
# 0                                    NaN  tt2637294                en
# 1                                    NaN  tt0368933                en
# 2      http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                    NaN  tt0093743                en
# 6     http://www.thepossessionmovie.com/  tt0431021                en
# ...                                  ...        ...               ...
# 2994                                 NaN  tt0105327                en
# 2995                                 NaN  tt0109403                en
# 2997                                 NaN  tt0116908                en
# 2998      http://www.alongcamepolly.com/  tt0343135                en
# 2999    http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 5       Pinocchio and the Emperor of the Night
# 6                               The Possession
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 5     Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6     A young girl buys an antique box at a yard sal...    7.286477  ...
# ...                                                 ...         ...  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 0         2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1          8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2        10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5          8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6         8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...           ...     ...                                       ...       ...
# 2994      9/18/92   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 5                                                   NaN
# 6                  Fear The Demon That Doesn't Fear God
# ...                                                 ...
# 2994  Just because you’re accepted doesn’t mean you ...
# 2995  It was supposed to be a routine prisoner trans...
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 5       Pinocchio and the Emperor of the Night
# 6                               The Possession
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6     [{'cast_id': 23, 'character': 'Clyde', 'credit...
# ...                                                 ...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 5     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# 6     [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075
# ...                                                 ...        ...
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [2575 rows x 23 columns]

# %%
english_movie=df[df["original_language"] =="en"]
english_movie
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                 homepage    imdb_id original_language  \
# 0                                    NaN  tt2637294                en
# 1                                    NaN  tt0368933                en
# 2      http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                    NaN  tt0093743                en
# 6     http://www.thepossessionmovie.com/  tt0431021                en
# ...                                  ...        ...               ...
# 2994                                 NaN  tt0105327                en
# 2995                                 NaN  tt0109403                en
# 2997                                 NaN  tt0116908                en
# 2998      http://www.alongcamepolly.com/  tt0343135                en
# 2999    http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 5       Pinocchio and the Emperor of the Night
# 6                               The Possession
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 5     Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6     A young girl buys an antique box at a yard sal...    7.286477  ...
# ...                                                 ...         ...  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 0         2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1          8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2        10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5          8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6         8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...           ...     ...                                       ...       ...
# 2994      9/18/92   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 5                                                   NaN
# 6                  Fear The Demon That Doesn't Fear God
# ...                                                 ...
# 2994  Just because you’re accepted doesn’t mean you ...
# 2995  It was supposed to be a routine prisoner trans...
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 5       Pinocchio and the Emperor of the Night
# 6                               The Possession
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6     [{'cast_id': 23, 'character': 'Clyde', 'credit...
# ...                                                 ...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 5     [{'credit_id': '52fe46f49251416c9106558b', 'de...    3261638
# 6     [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075
# ...                                                 ...        ...
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [2575 rows x 23 columns]

# %%
#how to write file in csv format
english_movie.to_csv("english_movie.csv")# data open in excel

# %% [markdown]
# # **Machine learning**

# %% [markdown]
# supervised learning

# %%
#supervised learning
# it is type of machine learning which is deal with label data type;
#supervised ml is solved two types of problem
#1=Regression based problem
#2= classification based problem

# %% [markdown]
# Reggresion based problem

# %%
# 1=Reggresion based problem
# the output feature in reggresion based problem is in continous form.   e.g- package prediction
# -supervised ml algorithm solved reggresion based problem
# 1-linear reggresion
# 2-ridge reggresion
#3-supportuection reggresion
#4-dicision tree reggresion
#5-random forest  reggresion

# %% [markdown]
# classification based problem

# %%
# the output feature of this type of problem is discrete
# e.g-result prediction ( binary classification problem)p-1,f-0
# marks      result
#  90         p-1
#   30        f-0
#   60        p-1

# %%
# supervised ml algorithm  solved classification based problem
#1 logistic regression
#2 support tree classification

# %% [markdown]
# 3 decision tree calssification
#
#
# 4- random forest classification
#
#
#
# for example--1 spam email detection
#
# 2 disease prediction
#
# if you have two class is known as  Binary classification.
#
# if you have more than two class is known as multiplication.

# %% [markdown]
# # unsupervised machine **learning**
#
#
# it is a type of machine learning which deal with unlabel data.
#
# it is solved following type of problem
#
# 1. clustring -grouping
#
# 2. dimensional reduction
#
# 3. anomaly detection
#
# 4. association
# ------
#
# # unsupervised machine learning algorithm
#
# 1. k-mean clustring
#
# 2. principal component analysis
#
#
#
#
# -----
#
#
# # **what is linear reggresion**
#
# it is supervised ml algorithm which is solved reggresion based problem.
#
# their are three type of linear reggresion
#
# 1. simple linear reggresion (y=mx+c)
#
# 2. multi linear reggresion (y=m1x1+m2x2+c)
#
# 3. polynomial linear reggresion (y=b0+b1x1+b2x1^2)

# %% [markdown]
# # **simple linear reggresion**
#
# y=mx+b

# %% [markdown]
# # **what is deep learning**
#
# .it is subset of ai and ml
#
# . it is based logical structure is known as neural
#
#  network this neural network inspired by human brain
#
#
# ---
#
#
#
#
#  **problem**-> result prediction
#
#
#  x1 python marks---------------x2 genai marks----------------y result
#
#  20----------------------------30------------------------------0
#
#  50----------------------------60------------------------------1
#
#
#
# ---
#
#
#
# 0-> neuron or preception
#
#
# ---
#
#
#
#
# # **what is perceptron**
#
#
#
# *   it is a algorithm or set of rules
#
# *   it is a simple model of neuron in artificial neural network
#
#
#
# *   perciptron receive input ,this input mutliply by weight then add bias and apply activation function.
#
#
# * perceptron is the building block of deep learning.
#
#
# # *activation function*-> it is mathematical function which is applied on neuron. it is represent non-linearity in the data.
#
#
#
# *   activation function determine the output of the neuron.
#
#
# # *  type of activation function
#
#
#
# 1.   sigmaid activation function-> it is work on binary classification,based problem.
#
# y=sigma(z) = 1/1+i^-2
#
# y=range(0 to 10)
#
#
# 2.   relu activation function-> mostly activation function
#
#       y=max(0,Z)
#
#       range-> 0 to infinity
#
#       domain -> 2-> -infinity to intfinity
#
#
#
#
#
#
# # *   Leaky relu activation function -> it is solved dead neuron problem
#
#  y=max(0.01z,z)
#
#  y=-infinty to infinity
#
#  domain -> z-> (-infinity to infinity)
#
#
# *   single perceptron not work on non - linear data
#
# but multi layer  perceptron work on non-linear data
#
#
#
# *   *ANN -> aritficial neural network*
#
#
#
#
# ---
#
#
#
# 1.   relu activation function in ANN used in hidden layer.
#
# 2.   if your problem is binary classification based then used sigmoid activation function in output layer.
#
#
#
# 1.if your problem is multiclassification based then used softmax activation function.(used in advanced machine learning)
#
#
# # **forward propagation**
#
# in forward propagation basically we took the input multiply by the weight then add as us comma apply activation function it intire process till the end.
#
#
# # **loss function**
#
# it is mathematical function that measure how well a  model pridiction match the actual value.
#
#
#
# 1.  loss function in regression based problem
#
#
# *   mean squared error (mse)
#
# mse =
#
#
#
# 2.   loss function in classification based problem
#
#
#
# *   *binary cross entropy*-> binary classification based problem
#
# *   *categorical cross entropy*-> multiclassification based problem
#
#
# # backword propagation **bold text**
#
#  backword propagation is a gradient estimation method commonly /used for training a neural network to compute its parameters update .
#
#  1-> weight updation formula.(baki copy pe)
#
#  2-> bias update formula.(baki copy pe)
#
# # what is learning rate
#
# learning rate is a hyper parameter that control the size of the weight adjustment during each itration of training.

# %% [markdown]
# # **transformer**
#
#
#
# *   transformer is a type of neural network in which we deal with sequence to sequence data.
#
#
# *   **Application**->  machine learning , question answering , text summarization.
#
#
#
# # **what is attention machanism**
#
#
#
# *   attention machanism enable nueral network to selecting and focus on specific part of input seqeunce.
#
#
#
# # **what is word embedding**
#
# [1 0 0 0 0 ]->sparse vectors
#
# [0.1 0.2 0.3 0.4 ]-> dense vectors
#
#
# -> word embedding natural lang proceed vectors.
#
#
# -> word embedding is a natural language processing technique  that convert word into numerical vector that allowing the computer to understand their meaning and the realationship of word.
#
#
# ->these numerical vectors are in dense form.
#
# -> **examples of word embedding:**
#
# 1. word to vector.
#
# 2. glove.
#
# 3. TF-IDF.
#
# # **Static word embedding->**
#
# in this embedding vector is single and fixed of each word.
#
# this embedding simple and fast.
#
#
# # **contextual word embedding ->**
#
# this embedding is dynamic contextual word embedding.
#
# contextual word embedding generate a unit vector for a word bassed on specific sentence.
#
# contextual word embedding are more accurate because they can capture different meaning of word such as the word bank in river bank versus river bank
#
#
# # **self attention machanism**( convert static word into contextual word)
#
#
# *   self attention is a way to convert static word embedding into contextual dynamic word embedding.
#
#
#
#
# ->**Positional encoding**--  provide transformer with information about the order of tokens in a sequence.
#
#
# # **Multihead attention machanism**
#
# it is a extension of self attention machanism .used in a transformer architecture.which allows the model to focus on different part of a input sequence from multiple purpose.
#
#
#
#
# **layer normalization** -- lays normalization  in a transformer is a important technique that stabalize and speed up model training .by normalizing the activation of each layer to have a mean of zero and standard deviation of one .
#
#
# **feed forword layer** --- this layer applied in a both part of the transformer encoder, and decoder.
#
#  1. this layer represent non linearity and capture complex pattern of the network.
#
#  **softmax layer**--  a softmax layer in a transformer convert a vector of rawscore into a probability distribution.
#
#  **1.their are two raws of softmax layer.**
#
#  ->in the attention machanism.
#
#  ->final output classification.
#
#
# # **masked multihead attention machanism**
#
# masked multihead attention machanism is used in the decoder of a transformer to pervent the model from seeing the future when pridicting next token in a sequence.
#
#
# # **Diffusion model**
#
#
# this model is generative ai model which generate high resolution image with varying quality.
#
# there are two diffusion process in diffusion model .
#
#
# 1.    froward diffusion process
# 2.   reverse diffusion process
#
#
# **forward diffusion** process is the markoff chain of diffusion step in which we slowly and randomly add noise in the  original data.
#
# **reverse diffusion** process is tries to reverse the diffusion processs to generate original data from the noise.
#
#
#
# # **Tokenisation**
#
# is the process of braking down text into smaller unit is called tokenisation.these token can be word ,subword or evens characters, depending on the approach.
#
#
#   tokenisation is fundamental NLP and gen ai.
#
#
#   **text->** gen ai is fascinating.
#
#   **token->** 'gen','ai','is','fascinating'
#
#
# # **subword tokenisation or subtoken**
#
#
# subword  tokenisation involves breaking word into smaller,meaning subword unit .
#
# **word->** fascination
#
# **subtoken->** 'fas','cina','tion'

# %% [markdown]
# # **COSINE SIMILARITY**
#
#
# cosines similarity is a matrix used to measure how similars to vectors are ,regardless of their magnitude.
#
# it is used in text analysis recomendation system and culestring task.

# %%
import numpy as np
from numpy.linalg import norm

A=np.array([2,1,2,3,2,9])
B=np.array([3,4,2,4,5,5])

#computr cosine similarity
cosine=np.dot(A,B)/(norm(A)*norm(B))
print("cosine similarity:",cosine)
# Out:
# cosine similarity: 0.8188504723485274

# %% [markdown]
# # **Tempature**
#
# **what is temp in llms?**
#
#
# *   tempature is a parameter that determines the probability distribution of the next word in text generation. it controlling the randomness and diversity of the output:
#
# low temperature(e.g.0.0-
#
# *   List item
#
#
#
#
#
# # **what is text summarization?**
#
# text summarization is the proces of generationg a short version of a text that preserves its main meaning,key ideas

# %% [markdown]
# # **HUGGING FACE TRANSFORMER LIBRARY**
#
# PIPELINE--

# %%
from transformers import pipeline

summarizer= pipeline("summarization",model="facebook/bart-large-cnn")
text="""Nature is the vast, beautiful world of physical and biological phenomena,
 providing essential resources like oxygen, food, and water for all life.
  It encompasses everything from the subatomic to the cosmic, including living organisms,
  mountains, rivers, and the sky. This delicate ecosystem sustains us,
   making it our shared responsibility to protect it from harm for the well-being of future generations. """
summary=summarizer(text,max_length=30,min_length=10,do_sample=False)
print(summary[0])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# {'summary_text': 'Nature is the vast, beautiful world of physical and biological phenomena. It encompasses everything from the subatomic to the cosmic, including living organisms'}

# %% [markdown]
# ANN- TABULAR DATA
#
# CNN- IMAGE DATA
#
# RNN/LSTM- SEQUENTIAL DATA
#
# LSTM--- long short term memory network
#
# ENCODER-DECODER -- it is a type of neural network. it is work on sequence to sequence
#
# machine translation/language translation
#
# e.g--- nice to meet you(encoder)
#
# in hindi( apse milkar acha laga)(decoder)
#
# encoder architecture
